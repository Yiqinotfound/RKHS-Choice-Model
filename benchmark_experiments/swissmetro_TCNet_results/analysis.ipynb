# %%
import pandas as pd
import sys 
sys.path.append("../../")
from utils.model_utils import load_config

# %%
data = pd.read_csv("swissmetro_TCNet_results.csv")
config_path = "../../configs/benchmark_config.yaml"
model_args = load_config(config_path)["swissmetro_TCNet"]

# %%
# data['max_epochs'] = 50
# # 把 max_epochs这列移到nll_train_loss这列前面
# data.insert(data.columns.get_loc('nll_train'), 'max_epochs', data.pop('max_epochs'))

# %%
data.groupby(list(model_args.keys())).mean()
# Out:
#                                                                                                                                                                                    fold  \
# num_heads hidden_dim drop_out weight_decay batch_size step_size learning_rate SEED max_epochs prod_fea emb_need multi_purchase preprocess_mode test_size n_splits gamma smoothing
# 16        128        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        5.0
#           256        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        5.0
#           512        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        5.0
#
#                                                                                                                                                                                    input_dim  \
# num_heads hidden_dim drop_out weight_decay batch_size step_size learning_rate SEED max_epochs prod_fea emb_need multi_purchase preprocess_mode test_size n_splits gamma smoothing
# 16        128        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01            89.0
#           256        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01            89.0
#           512        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01            89.0
#
#                                                                                                                                                                                    nll_train  \
# num_heads hidden_dim drop_out weight_decay batch_size step_size learning_rate SEED max_epochs prod_fea emb_need multi_purchase preprocess_mode test_size n_splits gamma smoothing
# 16        128        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        0.569148
#           256        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        0.544918
#           512        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        0.561992
#
#                                                                                                                                                                                     nll_val  \
# num_heads hidden_dim drop_out weight_decay batch_size step_size learning_rate SEED max_epochs prod_fea emb_need multi_purchase preprocess_mode test_size n_splits gamma smoothing
# 16        128        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.639212
#           256        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.618387
#           512        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.630303
#
#                                                                                                                                                                                    nll_test  \
# num_heads hidden_dim drop_out weight_decay batch_size step_size learning_rate SEED max_epochs prod_fea emb_need multi_purchase preprocess_mode test_size n_splits gamma smoothing
# 16        128        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.603893
#           256        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.581043
#           512        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.593610
#
#                                                                                                                                                                                    acc_train  \
# num_heads hidden_dim drop_out weight_decay batch_size step_size learning_rate SEED max_epochs prod_fea emb_need multi_purchase preprocess_mode test_size n_splits gamma smoothing
# 16        128        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        0.752125
#           256        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        0.764590
#           512        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        0.757515
#
#                                                                                                                                                                                     acc_val  \
# num_heads hidden_dim drop_out weight_decay batch_size step_size learning_rate SEED max_epochs prod_fea emb_need multi_purchase preprocess_mode test_size n_splits gamma smoothing
# 16        128        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.720640
#           256        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.732664
#           512        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.725094
#
#                                                                                                                                                                                    acc_test  \
# num_heads hidden_dim drop_out weight_decay batch_size step_size learning_rate SEED max_epochs prod_fea emb_need multi_purchase preprocess_mode test_size n_splits gamma smoothing
# 16        128        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.715796
#           256        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.735593
#           512        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01       0.726161
#
#                                                                                                                                                                                    train_time
# num_heads hidden_dim drop_out weight_decay batch_size step_size learning_rate SEED max_epochs prod_fea emb_need multi_purchase preprocess_mode test_size n_splits gamma smoothing
# 16        128        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        64.930361
#           256        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        66.187435
#           512        0.1      0            256        10        0.001         42   100        0        True     False          rumnet          0.1       9        0.95  0.01        70.762064
