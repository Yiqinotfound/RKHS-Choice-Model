# %%
import pandas as pd
import sys 
sys.path.append("../../")
from utils.model_utils import load_config

# %%
data = pd.read_csv("swissmetro_FK_results.csv")
config_path = "../../configs/exp_config.yaml"
model_args = load_config(config_path)["swiss_metro_fk_args"]

# %%
data.groupby(list(model_args.keys()) + ['kernel_params']).mean()
# Out:
#                                                                                                                                                                  fold  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1   5.0
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4   5.0
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1   5.0
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1   5.0
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1          5.0
#                                                                                                                                   sigma=5_length_scale=1          5.0
#
#                                                                                                                                                                  nll_train  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1   0.292720
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4   0.355131
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1   0.391044
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1   0.406518
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1          0.750034
#                                                                                                                                   sigma=5_length_scale=1          0.420568
#
#                                                                                                                                                                   nll_val  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1  0.648584
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4  0.566541
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1  0.623567
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1  0.622236
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1         0.753343
#                                                                                                                                   sigma=5_length_scale=1         0.620226
#
#                                                                                                                                                                  nll_test  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1  0.381353
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4  0.421753
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1  0.468330
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1  0.482346
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1         0.761376
#                                                                                                                                   sigma=5_length_scale=1         0.497542
#
#                                                                                                                                                                  acc_train  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1   0.899697
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4   0.867109
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1   0.832059
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1   0.820631
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1          0.657782
#                                                                                                                                   sigma=5_length_scale=1          0.810654
#
#                                                                                                                                                                   acc_val  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1  0.723125
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4  0.749974
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1  0.723229
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1  0.720431
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1         0.655232
#                                                                                                                                   sigma=5_length_scale=1         0.717425
#
#                                                                                                                                                                  acc_test  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1  0.845667
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4  0.818097
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1  0.783167
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1  0.777156
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1         0.636816
#                                                                                                                                   sigma=5_length_scale=1         0.763682
#
#                                                                                                                                                                  train_time  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1   28.488804
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4   69.622170
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1   28.640674
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1   29.045498
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1          67.891718
#                                                                                                                                   sigma=5_length_scale=1          32.215079
#
#                                                                                                                                                                  precompute_time  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1        90.187631
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4        89.652876
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1        93.008804
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1       194.753705
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1                0.189623
#                                                                                                                                   sigma=5_length_scale=1                0.189991
#
#                                                                                                                                                                  precompute_time_train  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1              72.155361
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4              71.718255
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1              74.422214
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1             155.824617
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1                      0.023217
#                                                                                                                                   sigma=5_length_scale=1                      0.023233
#
#                                                                                                                                                                  precompute_time_val  \
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1             9.012380
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4             8.962849
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1             9.289922
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1            19.460577
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1                    0.001411
#                                                                                                                                   sigma=5_length_scale=1                    0.001422
#
#                                                                                                                                                                  precompute_time_test
# kernel_type SEED learning_rate lambda  patience alpha_std smoothing n_splits test_size precompute_batch_size optimizer max_epochs kernel_params
# 0.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=0.5_length_scale=1              9.018712
#                                                                                                                                   sigma=5_nu=0.5_length_scale=4              8.970576
# 1.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=1.5_length_scale=1              9.295498
# 2.5matern   42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        sigma=5_nu=2.5_length_scale=1             19.467303
# gaussian    42   0.01          0.00005 20       0.01      0.01      9        0.1       1500                  LBFGS     100        length_scale=5_sigma=1                     0.001378
#                                                                                                                                   sigma=5_length_scale=1                     0.001386
