# %%
import pandas as pd
import sys 
sys.path.append("../../")
from utils.model_utils import load_config

# %%
data = pd.read_csv("swissmetro_NTK_results.csv")
config_path = "../../configs/exp_config.yaml"
model_args = load_config(config_path)["attention_ntk_model_args"]

# %%
data.groupby(list(model_args.keys())).mean()
# Out:
#                                                                                                                                                           fold  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    1000 0.01  0.9      0                   20       9        rumnet            5.0
#
#                                                                                                                                                           nll_train  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    1000 0.01  0.9      0                   20       9        rumnet            0.380781
#
#                                                                                                                                                            nll_val  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    1000 0.01  0.9      0                   20       9        rumnet           0.538627
#
#                                                                                                                                                           nll_test  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    1000 0.01  0.9      0                   20       9        rumnet           0.436466
#
#                                                                                                                                                           acc_train  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    1000 0.01  0.9      0                   20       9        rumnet            0.846636
#
#                                                                                                                                                            acc_val  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    1000 0.01  0.9      0                   20       9        rumnet           0.780244
#
#                                                                                                                                                           acc_test  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    1000 0.01  0.9      0                   20       9        rumnet           0.815609
#
#                                                                                                                                                           train_time
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    1000 0.01  0.9      0                   20       9        rumnet            66.185447
