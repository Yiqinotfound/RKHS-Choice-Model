# %%
import pandas as pd
import sys 
sys.path.append("../../")
from utils.model_utils import load_config

# %%
data = pd.read_csv("swissmetro_NTK_results.csv")
config_path = "../../configs/exp_config.yaml"
model_args = load_config(config_path)["attention_ntk_model_args"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_csv("swissmetro_NTK_results.csv")
#       2 config_path = "../../configs/exp_config.yaml"
#       3 model_args = load_config(config_path)["attention_ntk_model_args"]
#
# NameError: name 'pd' is not defined

# %%
# data['max_epochs'] = 50
# # 把 max_epochs这列移到nll_train_loss这列前面
# data.insert(data.columns.get_loc('nll_train'), 'max_epochs', data.pop('max_epochs'))

# %%
data.groupby(list(model_args.keys())).mean()
# Out:
#                                                                                                                                                                                            fold  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode max_epochs mixed_precision half
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    32   0.01  0.9      0                   20       9        rumnet          50         False           False   5.0
#                                                                                100  0.01  0.9      0                   20       9        rumnet          100        False           False   5.0
#                                                                                1000 0.01  0.9      0                   20       9        rumnet          50         False           False   5.0
#                                                                                                                        30       9        rumnet          100        False           False   5.0
#                                                                                2000 0.01  0.9      0                   20       9        rumnet          50         False           False   5.0
#                                                                                4000 0.01  0.9      0                   20       9        rumnet          100        False           False   5.0
#
#                                                                                                                                                                                            nll_train  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode max_epochs mixed_precision half
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    32   0.01  0.9      0                   20       9        rumnet          50         False           False   0.418335
#                                                                                100  0.01  0.9      0                   20       9        rumnet          100        False           False   0.391594
#                                                                                1000 0.01  0.9      0                   20       9        rumnet          50         False           False   0.380781
#                                                                                                                        30       9        rumnet          100        False           False   0.359411
#                                                                                2000 0.01  0.9      0                   20       9        rumnet          50         False           False   0.360074
#                                                                                4000 0.01  0.9      0                   20       9        rumnet          100        False           False   0.356457
#
#                                                                                                                                                                                             nll_val  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode max_epochs mixed_precision half
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    32   0.01  0.9      0                   20       9        rumnet          50         False           False  0.563821
#                                                                                100  0.01  0.9      0                   20       9        rumnet          100        False           False  0.546566
#                                                                                1000 0.01  0.9      0                   20       9        rumnet          50         False           False  0.538627
#                                                                                                                        30       9        rumnet          100        False           False  0.533095
#                                                                                2000 0.01  0.9      0                   20       9        rumnet          50         False           False  0.531706
#                                                                                4000 0.01  0.9      0                   20       9        rumnet          100        False           False  0.527500
#
#                                                                                                                                                                                            nll_test  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode max_epochs mixed_precision half
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    32   0.01  0.9      0                   20       9        rumnet          50         False           False  0.483406
#                                                                                100  0.01  0.9      0                   20       9        rumnet          100        False           False  0.456647
#                                                                                1000 0.01  0.9      0                   20       9        rumnet          50         False           False  0.436466
#                                                                                                                        30       9        rumnet          100        False           False  0.422883
#                                                                                2000 0.01  0.9      0                   20       9        rumnet          50         False           False  0.419556
#                                                                                4000 0.01  0.9      0                   20       9        rumnet          100        False           False  0.416485
#
#                                                                                                                                                                                            acc_train  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode max_epochs mixed_precision half
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    32   0.01  0.9      0                   20       9        rumnet          50         False           False   0.831761
#                                                                                100  0.01  0.9      0                   20       9        rumnet          100        False           False   0.842762
#                                                                                1000 0.01  0.9      0                   20       9        rumnet          50         False           False   0.846636
#                                                                                                                        30       9        rumnet          100        False           False   0.858233
#                                                                                2000 0.01  0.9      0                   20       9        rumnet          50         False           False   0.858706
#                                                                                4000 0.01  0.9      0                   20       9        rumnet          100        False           False   0.860151
#
#                                                                                                                                                                                             acc_val  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode max_epochs mixed_precision half
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    32   0.01  0.9      0                   20       9        rumnet          50         False           False  0.770913
#                                                                                100  0.01  0.9      0                   20       9        rumnet          100        False           False  0.777030
#                                                                                1000 0.01  0.9      0                   20       9        rumnet          50         False           False  0.780244
#                                                                                                                        30       9        rumnet          100        False           False  0.786929
#                                                                                2000 0.01  0.9      0                   20       9        rumnet          50         False           False  0.788225
#                                                                                4000 0.01  0.9      0                   20       9        rumnet          100        False           False  0.788848
#
#                                                                                                                                                                                            acc_test  \
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode max_epochs mixed_precision half
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    32   0.01  0.9      0                   20       9        rumnet          50         False           False  0.800269
#                                                                                100  0.01  0.9      0                   20       9        rumnet          100        False           False  0.809183
#                                                                                1000 0.01  0.9      0                   20       9        rumnet          50         False           False  0.815609
#                                                                                                                        30       9        rumnet          100        False           False  0.827218
#                                                                                2000 0.01  0.9      0                   20       9        rumnet          50         False           False  0.829706
#                                                                                4000 0.01  0.9      0                   20       9        rumnet          100        False           False  0.830120
#
#                                                                                                                                                                                            train_time
# smoothing test_size SEED learning_rate add_noise batch_size tau     activation H    sigma momentum grad_norm_threshold patience n_splits preprocess_mode max_epochs mixed_precision half
# 0.01      0.1       42   0.01          True      512        0.00001 softmax    32   0.01  0.9      0                   20       9        rumnet          50         False           False    6.483284
#                                                                                100  0.01  0.9      0                   20       9        rumnet          100        False           False    7.472414
#                                                                                1000 0.01  0.9      0                   20       9        rumnet          50         False           False   66.185447
#                                                                                                                        30       9        rumnet          100        False           False  108.557303
#                                                                                2000 0.01  0.9      0                   20       9        rumnet          50         False           False  133.192541
#                                                                                4000 0.01  0.9      0                   20       9        rumnet          100        False           False  268.070697
