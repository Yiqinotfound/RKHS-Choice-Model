# %%
import pandas as pd
import sys 
sys.path.append("../../")
from utils.model_utils import load_config

# %%
data = pd.read_csv("swissmetro_RF_results.csv")
config_path = "../../configs/exp_config.yaml"
model_args = load_config(config_path)["swiss_metro_rf_args"]

# %%
data.groupby(list(model_args.keys())).mean()
# Out:
#                                                                                                                                                          fold  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 1}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 5        42   0.01            5.0
#             {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01            5.0
#             {'sigma': 5, 'lengthscale': 4}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01            5.0
#
#                                                                                                                                                            lr  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 1}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 5        42   0.01           0.10
#             {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.01
#             {'sigma': 5, 'lengthscale': 4}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.01
#
#                                                                                                                                                          nll_train  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 1}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 5        42   0.01            0.458802
#             {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01            0.416879
#             {'sigma': 5, 'lengthscale': 4}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01            0.444754
#
#                                                                                                                                                           nll_val  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 1}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 5        42   0.01           0.604537
#             {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.527822
#             {'sigma': 5, 'lengthscale': 4}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.536988
#
#                                                                                                                                                          nll_test  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 1}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 5        42   0.01           0.534686
#             {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.461444
#             {'sigma': 5, 'lengthscale': 4}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.480669
#
#                                                                                                                                                          acc_train  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 1}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 5        42   0.01            0.794444
#             {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01            0.839562
#             {'sigma': 5, 'lengthscale': 4}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01            0.826734
#
#                                                                                                                                                           acc_val  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 1}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 5        42   0.01           0.711517
#             {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.782939
#             {'sigma': 5, 'lengthscale': 4}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.775786
#
#                                                                                                                                                          acc_test
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 1}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 5        42   0.01           0.741190
#             {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.811360
#             {'sigma': 5, 'lengthscale': 4}   20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     1.000000e-10 10       42   0.01           0.797678
