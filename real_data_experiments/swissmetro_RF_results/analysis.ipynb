# %%
import pandas as pd
import sys 
sys.path.append("../../")
from utils.model_utils import load_config

# %%
data = pd.read_csv("swissmetro_RF_results.csv")
config_path = "../../configs/exp_config.yaml"
model_args = load_config(config_path)["swiss_metro_rf_args"]

# %%
data.groupby(list(model_args.keys())).mean()
# Out:
#                                                                                                                                                               fold  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lr   lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     0.01 1.000000e-10 10       42   0.01            5.0
#
#                                                                                                                                                               nll_train  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lr   lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     0.01 1.000000e-10 10       42   0.01            0.416852
#
#                                                                                                                                                                nll_val  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lr   lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     0.01 1.000000e-10 10       42   0.01           0.527765
#
#                                                                                                                                                               nll_test  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lr   lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     0.01 1.000000e-10 10       42   0.01           0.462402
#
#                                                                                                                                                               acc_train  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lr   lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     0.01 1.000000e-10 10       42   0.01            0.839225
#
#                                                                                                                                                                acc_val  \
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lr   lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     0.01 1.000000e-10 10       42   0.01           0.783146
#
#                                                                                                                                                               acc_test
# kernel_type kernel_params                    Nw    rho  tol          eps          smoothing n_splits theta_std lr   lambda       patience SEED learning_rate
# gaussian    {'sigma': 5, 'lengthscale': 3.6} 20000 1000 1.000000e-09 1.000000e-09 0.01      9        0.001     0.01 1.000000e-10 10       42   0.01           0.813018
