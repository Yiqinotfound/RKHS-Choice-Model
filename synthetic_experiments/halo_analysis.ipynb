# %%
import pandas as pd

# %%
rkhs_data = pd.read_csv("/data/yiqi/RKHSChoiceModel/Halo/results/rkhs_second_order_results_3.csv")

# %%
rkhs_data = pd.read_csv("/data/yiqi/RKHSChoiceModel/Halo/results/rkhs_first_order_results_2_8.csv")
# rkhs_result = rkhs_data.groupby(['kernel_type','mask','lambda'])[["nll","hard_rmse","soft_rmse","train_time"]].mean()
# rkhs_result = rkhs_result.round(5)
rkhs_data
# Out:
#    kernel_type          kernel_params   mask       nll  hard_rmse  soft_rmse  \
# 0       linear  {'degree': 1, 'c': 0}  False  0.754952   0.379972   0.018107
# 1       linear  {'degree': 1, 'c': 0}   True  0.754505   0.379969   0.017934
# 2       linear  {'degree': 1, 'c': 0}  False  0.755004   0.379971   0.018046
# 3       linear  {'degree': 1, 'c': 0}   True  0.754505   0.379969   0.017932
# 4       linear  {'degree': 1, 'c': 0}  False  0.754972   0.379970   0.018029
# 5       linear  {'degree': 1, 'c': 0}   True  0.754505   0.379969   0.017905
# 6       linear  {'degree': 1, 'c': 0}  False  0.755113   0.379971   0.018010
# 7       linear  {'degree': 1, 'c': 0}   True  0.754505   0.379969   0.017932
# 8       linear  {'degree': 1, 'c': 0}  False  0.754922   0.379973   0.018109
# 9       linear  {'degree': 1, 'c': 0}   True  0.754505   0.379969   0.017917
# 10      linear  {'degree': 1, 'c': 0}  False  0.755040   0.379977   0.018143
# ...

# %%
cmnl_data = pd.read_csv("/data/yiqi/RKHSChoiceModel/Halo/results/cmnl_first_order_results_2_8.csv")
cmnl_data.mean()
# Out:
# nll           0.754674
# hard_rmse     0.379993
# soft_rmse     0.018333
# train_time    3.204346
# dtype: float64

# %%
import torch
S = torch.load("/data/yiqi/RKHSChoiceModel/Halo/results/1.pt")
# Out:
# /tmp/ipykernel_3555280/3187035102.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   S = torch.load("/data/yiqi/RKHSChoiceModel/Halo/results/1.pt")
